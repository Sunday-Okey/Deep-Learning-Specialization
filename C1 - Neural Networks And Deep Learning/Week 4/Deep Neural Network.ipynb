# %% [markdown]
# ## Deep Neural Network

# %% [markdown]
# Analyze the key computations underlying deep learning, then use them to build and train deep neural networks for computer vision tasks.

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - Describe the successive block structure of a deep neural network
# - Build a deep L-layer neural network
# - Analyze matrix and vector dimensions to check neural network implementations
# - Use a cache to pass information from forward to back propagation
# - Explain the role of hyperparameters in deep learning
# - Build a 2-layer neural network

# %% [markdown]
# ![image.png](attachment:abac5f1e-fc14-4256-a64e-86dac32a34d1.png)

# %% [markdown]
# ![image.png](attachment:550e9985-eb36-44b4-81ee-c46cc8260d68.png)

# %% [markdown]
# ![image.png](attachment:9778184b-f253-4255-9410-a4fca60e8f0d.png)

# %% [markdown]
# ## Forward Propagation in a Deep Network

# %% [markdown]
# ![image.png](attachment:1c12f0b8-e8af-4e7e-84f9-90e0e29da525.png)
