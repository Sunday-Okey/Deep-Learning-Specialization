# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# ![image.png](attachment:f9c76d36-5093-46a7-9a5d-152717e131dd.png)

# %% [markdown]
# ![image.png](attachment:53f43012-bf05-4aea-aef4-fa3a57328329.png)

# %% [markdown]
# ![image.png](attachment:ba5ce0c1-080a-496a-aa88-48bce18140b4.png)

# %% [markdown]
# ## Edge Detection Example

# %% [markdown]
# ![image.png](attachment:df5bf9b4-f489-47d6-af89-8aadf1f1490c.png)

# %% [markdown]
# ![image.png](attachment:a94db724-5013-4122-8436-07d96fc5c9f6.png)

# %% [markdown]
# ![image.png](attachment:25850f78-8349-400b-9614-7768ddbf0140.png)

# %% [markdown]
# ![image.png](attachment:3e6d2b00-35ed-4df1-bcab-aa6b2f6f4f03.png)

# %% [markdown]
# ## More Edge Detection

# %% [markdown]
# ![image.png](attachment:7c804d50-be92-4e78-8439-b3d01118150e.png)

# %% [markdown]
# ![image.png](attachment:10c54314-4cc6-49c5-9cd9-dfb2f5e8abb3.png)

# %% [markdown]
# ![image.png](attachment:d04f4562-c9a5-4de3-a0d0-9ebeb356d920.png)
